# %% [markdown]
# [# Google Colab Link](https://colab.research.google.com/drive/1sVJpwSla2F7ZaW6Vs9gGYj8OiEAP1vAN?usp=sharing)

# %% [markdown]
# # Secret API Manager
# To access the API you need a secret key. You can get this by requesting it from MyTelescope. Once you have it, it's good practice to add it safely in the Secrets tab on the left (the key icon) and load it with the code below. That way you don't leave your secret exposed in your code. The code below uses "my_telescope" as the secret name.

# %%
from google.colab import userdata
API_KEY = userdata.get('my_telescope')

# %% [markdown]
# # Load Libary from Growth Dynamics Shared Assets

# %%
# !wget -O mytelescope.py https://raw.githubusercontent.com/growthdynamics/shared_assets/main/share_search/mytelescope.py

from mytelescope import (
    fetch_all_states_data,
    calculate_yoy_metrics,
    create_us_map_with_labels,
    create_us_map_current,
    generate_state_report_html,
    generate_state_report
  )

import pandas as pd
# Out:
# --2026-01-13 20:07:09--  https://raw.githubusercontent.com/growthdynamics/shared_assets/main/share_search/mytelescope.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32605 (32K) [text/plain]
# Saving to: ‘mytelescope.py’
#
# mytelescope.py      100%[===================>]  31.84K  --.-KB/s    in 0.004s
#
# 2026-01-13 20:07:09 (8.64 MB/s) - ‘mytelescope.py’ saved [32605/32605]

# %%
# =============================================================================
# Configuration
# =============================================================================

USE_DEMO_DATA = False  # Set to False to use live API

brand = "New Balance"

# =============================================================================
# Load Data
# =============================================================================

if USE_DEMO_DATA:
    print("📦 Loading demo data...")
    demo_url = "https://raw.githubusercontent.com/growthdynamics/shared_assets/main/share_search/mytelescope_colab_demo_data.csv"
    df = pd.read_csv(demo_url)
    df['date'] = pd.to_datetime(df['date'])  # Ensure date parsing
else:
    print("🔌 Fetching live data from API...")
    from google.colab import userdata
    API_KEY = userdata.get('my_telescope')

    DASHBOARDS = {
        "New York": "wuHRyDshXjdjO80kAzyu",
        "California": "xFpVC7HfkVlyPTd0LIb1",
        "Texas": "6PP59FMD84hKczxofJaU"
    }

    df = fetch_all_states_data(API_KEY, DASHBOARDS)

print(f"✓ Loaded {len(df):,} rows across {df['state'].nunique()} states")

# =============================================================================
# Calculate Metrics
# =============================================================================

metrics = calculate_yoy_metrics(df, brand=brand)
# Out:
# 🔌 Fetching live data from API...
# Fetching New York... ✓ (144 rows)
# Fetching California... ✓ (144 rows)
# Fetching Texas... ✓ (144 rows)
# ✓ Loaded 432 rows across 3 states

# %%
# Single map with both metrics as labels
fig = create_us_map_with_labels(metrics, brand=brand)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="6cd996dd-b296-4055-9ddc-5c8e6a5db15d" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6cd996dd-b296-4055-9ddc-5c8e6a5db15d")) {                    Plotly.newPlot(                        "6cd996dd-b296-4055-9ddc-5c8e6a5db15d",                        [{"colorbar":{"title":{"text":"SoS YoY (pp)"},"x":1.0},"colorscale":[[0.0,"rgb(165,0,38)"],[0.1,"rgb(215,48,39)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(217,239,139)"],[0.7,"rgb(166,217,106)"],[0.8,"rgb(102,189,99)"],[0.9,"rgb(26,152,80)"],[1.0,"rgb(0,104,55)"]],"customdata":[[3.8,1.8],[-0.4,-16.2],[1.9,-1.6]],"hovertemplate":"\u003cb\u003e%{text}\u003c\u002fb\u003e\u003cbr\u003eSoS YoY: %{customdata[0]:+.1f}pp\u003cbr\u003eVol YoY: %{customdata[1]:+.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["CA","NY","TX"],"text":["California","New York","Texas"],"z":[3.8,-0.4,1.9],"zmid":0,"type":"choropleth"},{"hoverinfo":"skip","lat":[37.2],"lon":[-119.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eCA\u003cbr\u003eSoS: +3.8pp\u003cbr\u003eVol: +1.8%\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[42.9],"lon":[-75.5],"mode":"text","showlegend":false,"text":["\u003cb\u003eNY\u003cbr\u003eSoS: -0.4pp\u003cbr\u003eVol: -16.2%\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[31.5],"lon":[-99.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eTX\u003cbr\u003eSoS: +1.9pp\u003cbr\u003eVol: -1.6%\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %%
# You can also colour by volume instead of SoS
fig = create_us_map_current(metrics, brand=brand, color_by="current_volume")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="50489f09-40e7-441a-a59e-750ecfdf5818" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50489f09-40e7-441a-a59e-750ecfdf5818")) {                    Plotly.newPlot(                        "50489f09-40e7-441a-a59e-750ecfdf5818",                        [{"colorbar":{"title":{"text":"Volume"},"x":1.0},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"customdata":[[31.1,16656630.0],[29.3,10017210.0],[32.0,12557560.0]],"hovertemplate":"\u003cb\u003e%{text}\u003c\u002fb\u003e\u003cbr\u003eSoS: %{customdata[0]:.1f}%\u003cbr\u003eVolume: %{customdata[1]:,.0f}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["CA","NY","TX"],"text":["California","New York","Texas"],"z":[16656630,10017210,12557560],"type":"choropleth"},{"hoverinfo":"skip","lat":[37.2],"lon":[-119.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eCA\u003cbr\u003eSoS: 31.1%\u003cbr\u003eVol: 16.7M\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[42.9],"lon":[-75.5],"mode":"text","showlegend":false,"text":["\u003cb\u003eNY\u003cbr\u003eSoS: 29.3%\u003cbr\u003eVol: 10.0M\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[31.5],"lon":[-99.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eTX\u003cbr\u003eSoS: 32.0%\u003cbr\u003eVol: 12.6M\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666 ...

# %%
# HTML (interactive)
generate_state_report_html(df, output_path="state_report.html")
# Out:
# Generating HTML report for 3 states...
#   [1/3] California... ✓
#   [2/3] New York... ✓
#   [3/3] Texas... ✓
#
# Done! Report saved to: state_report.html
# 'state_report.html'

# %%
from google.colab import userdata
API_KEY = userdata.get('my_telescope')

DASHBOARDS = {
        "New York": "H7TwarRPQhpxSe7xbFaT",
        "California": "fREMTT5wOjnObWIKvmaL",
        "Texas": "JCh7wqT7TsNwynE1dBy3"
    }

df = fetch_all_states_data(API_KEY, DASHBOARDS)

df.head()
# Out:
# Fetching New York... ✓ (144 rows)
# Fetching California... ✓ (144 rows)
# Fetching Texas... ✓ (144 rows)
#         date                           topic  volume  percentage     state  \
# 0 2025-11-30  Running shoes - New York State  231560   22.428856  New York
# 1 2025-11-30       Sneakers - New York State  708120   68.588365  New York
# 2 2025-11-30   Tennis shoes - New York State   92740    8.982778  New York
# 3 2025-10-31  Running shoes - New York State  252750   25.283344  New York
# 4 2025-10-31       Sneakers - New York State  656200   65.641662  New York
#
#   state_abbrev
# 0           NY
# 1           NY
# 2           NY
# 3           NY
# 4           NY

# %%
brand = 'Running'

metrics = calculate_yoy_metrics(df, brand=brand)

# %%
# Single map with both metrics as labels
fig = create_us_map_with_labels(metrics, brand=brand)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="fe7eea87-e861-457e-839d-5025b1f01876" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fe7eea87-e861-457e-839d-5025b1f01876")) {                    Plotly.newPlot(                        "fe7eea87-e861-457e-839d-5025b1f01876",                        [{"colorbar":{"title":{"text":"SoS YoY (pp)"},"x":1.0},"colorscale":[[0.0,"rgb(165,0,38)"],[0.1,"rgb(215,48,39)"],[0.2,"rgb(244,109,67)"],[0.3,"rgb(253,174,97)"],[0.4,"rgb(254,224,139)"],[0.5,"rgb(255,255,191)"],[0.6,"rgb(217,239,139)"],[0.7,"rgb(166,217,106)"],[0.8,"rgb(102,189,99)"],[0.9,"rgb(26,152,80)"],[1.0,"rgb(0,104,55)"]],"customdata":[[9.2,19.0],[6.7,26.5],[9.0,20.1]],"hovertemplate":"\u003cb\u003e%{text}\u003c\u002fb\u003e\u003cbr\u003eSoS YoY: %{customdata[0]:+.1f}pp\u003cbr\u003eVol YoY: %{customdata[1]:+.1f}%\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["CA","NY","TX"],"text":["California","New York","Texas"],"z":[9.2,6.7,9.0],"zmid":0,"type":"choropleth"},{"hoverinfo":"skip","lat":[37.2],"lon":[-119.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eCA\u003cbr\u003eSoS: +9.2pp\u003cbr\u003eVol: +19.0%\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[42.9],"lon":[-75.5],"mode":"text","showlegend":false,"text":["\u003cb\u003eNY\u003cbr\u003eSoS: +6.7pp\u003cbr\u003eVol: +26.5%\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[31.5],"lon":[-99.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eTX\u003cbr\u003eSoS: +9.0pp\u003cbr\u003eVol: +20.1%\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555 ...

# %%
# You can also colour by volume instead of SoS
fig = create_us_map_current(metrics, brand=brand, color_by="current_volume")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0e5a9e4c-40ed-44bd-b5fa-37ddd8c16919" class="plotly-graph-div" style="height:600px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e5a9e4c-40ed-44bd-b5fa-37ddd8c16919")) {                    Plotly.newPlot(                        "0e5a9e4c-40ed-44bd-b5fa-37ddd8c16919",                        [{"colorbar":{"title":{"text":"Volume"},"x":1.0},"colorscale":[[0.0,"rgb(247,251,255)"],[0.125,"rgb(222,235,247)"],[0.25,"rgb(198,219,239)"],[0.375,"rgb(158,202,225)"],[0.5,"rgb(107,174,214)"],[0.625,"rgb(66,146,198)"],[0.75,"rgb(33,113,181)"],[0.875,"rgb(8,81,156)"],[1.0,"rgb(8,48,107)"]],"customdata":[[47.0,6788910.0],[22.4,2891520.0],[37.8,3658780.0]],"hovertemplate":"\u003cb\u003e%{text}\u003c\u002fb\u003e\u003cbr\u003eSoS: %{customdata[0]:.1f}%\u003cbr\u003eVolume: %{customdata[1]:,.0f}\u003cextra\u003e\u003c\u002fextra\u003e","locationmode":"USA-states","locations":["CA","NY","TX"],"text":["California","New York","Texas"],"z":[6788910,2891520,3658780],"type":"choropleth"},{"hoverinfo":"skip","lat":[37.2],"lon":[-119.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eCA\u003cbr\u003eSoS: 47.0%\u003cbr\u003eVol: 6.8M\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[42.9],"lon":[-75.5],"mode":"text","showlegend":false,"text":["\u003cb\u003eNY\u003cbr\u003eSoS: 22.4%\u003cbr\u003eVol: 2.9M\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"},{"hoverinfo":"skip","lat":[31.5],"lon":[-99.4],"mode":"text","showlegend":false,"text":["\u003cb\u003eTX\u003cbr\u003eSoS: 37.8%\u003cbr\u003eVol: 3.7M\u003c\u002fb\u003e"],"textfont":{"color":"black","family":"Arial Black","size":14},"type":"scattergeo"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666 ...

# %%
# HTML (interactive)
generate_state_report_html(df, output_path="state_report_product.html")
# Out:
# Generating HTML report for 3 states...
#   [1/3] California... ✓
#   [2/3] New York... ✓
#   [3/3] Texas... ✓
#
# Done! Report saved to: state_report_product.html
# 'state_report_product.html'
